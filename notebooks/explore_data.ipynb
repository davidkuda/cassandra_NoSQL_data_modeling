# %%
import pandas as pd

# %%
df = pd.read_csv('../data/event_datafile_new.csv')

# %%
df
# Out:
#                 artist firstName gender  itemInSession  lastName     length  \
# 0             Harmonia      Ryan      M              0     Smith  655.77751
# 1          The Prodigy      Ryan      M              1     Smith  260.07465
# 2                Train      Ryan      M              2     Smith  205.45261
# 3          Sony Wonder    Samuel      M              0  Gonzalez  218.06975
# 4            Van Halen     Tegan      F              2    Levine  289.38404
# ...                ...       ...    ...            ...       ...        ...
# 6815      Foo Fighters     Rylan      M             57    George  271.38567
# 6816        Timbiriche     Rylan      M             58    George  202.60526
# 6817  A Perfect Circle     Rylan      M             59    George  206.05342
# 6818          Anberlin     Rylan      M             60    George  348.68200
# 6819         Deas Vail    Elijah      M              0     Davis  237.68771
#
# ...

# %%
df.dtypes
# Out:
# artist            object
# firstName         object
# gender            object
# itemInSession      int64
# lastName          object
# length           float64
# level             object
# location          object
# sessionId          int64
# song              object
# userId             int64
# dtype: object
